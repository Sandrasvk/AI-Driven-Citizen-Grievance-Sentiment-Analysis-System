# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### Load the Dataset

# %%
df = pd.read_csv("311_Service_Requests_for_2009.csv",low_memory=False)

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    12822544  01/01/2009 12:00:00 AM  01/07/2009 12:00:00 AM    HPD
# 1    12818524  01/01/2009 12:00:00 AM                     NaN  DOHMH
# 2    12823061  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 3    12823062  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 4    12823063  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
#
#                                          Agency Name  \
# 0  Department of Housing Preservation and Develop...
# 1            Department of Health and Mental Hygiene
# 2                       Department of Transportation
# 3                       Department of Transportation
# 4                       Department of Transportation
#
#              Complaint Type         Descriptor               Location Type  \
# 0                   HEATING               HEAT        RESIDENTIAL BUILDING
# 1                   Smoking  Smoking Violation  Restaurant/Bar/Deli/Bakery
# 2  Traffic Signal Condition         Controller                         NaN
# 3  Traffic Signal Condition         Controller                         NaN
# 4  Traffic Signal Condition         Controller                         NaN
#
#   Incident Zip      Incident Address  ... Bridge Highway Name  \
# 0        11225    55 WINTHROP STREET  ...                 NaN
# 1        11102  29-35 NEWTOWN AVENUE  ...                 NaN
# 2        11220                   NaN  ...                 NaN
# 3        11201                   NaN  ...                 NaN
# 4        11235                   NaN  ...                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name  \
# 0                      NaN       NaN                    NaN             NaN
# 1                      NaN       NaN                    NaN             NaN
# 2                      NaN       NaN                    NaN             NaN
# 3                      NaN       NaN                    NaN             NaN
# 4                      NaN       NaN                    NaN             NaN
#
#   Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0             NaN                 NaN  40.656621 -73.958066
# 1             NaN                 NaN  40.768896 -73.921818
# 2             NaN                 NaN  40.635345 -74.016822
# 3             NaN                 NaN  40.698378 -73.983050
# 4             NaN                 NaN  40.592752 -73.950152
#
#                                    Location
# 0   (40.65662129596871, -73.95806621423951)
# 1   (40.76889608950418, -73.92181786912313)
# 2  (40.635344653337626, -74.01682221017914)
# 3  (40.698378448801606, -73.98305008771115)
# 4   (40.59275234651692, -73.95015246435702)
#
# [5 rows x 52 columns]

# %%
df.shape
# Out:
# (1783133, 52)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783133 entries, 0 to 1783132
# Data columns (total 52 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Unique Key                      int64
#  1   Created Date                    object
#  2   Closed Date                     object
#  3   Agency                          object
#  4   Agency Name                     object
#  5   Complaint Type                  object
#  6   Descriptor                      object
#  7   Location Type                   object
#  8   Incident Zip                    object
#  9   Incident Address                object
#  10  Street Name                     object
#  11  Cross Street 1                  object
#  12  Cross Street 2                  object
#  13  Intersection Street 1           object
#  14  Intersection Street 2           object
#  15  Address Type                    object
#  16  City                            object
#  17  Landmark                        object
#  18  Facility Type                   object
#  19  Status                          object
#  20  Due Date                        object
#  21  Resolution Action Updated Date  object
#  22  Community Board                 object
#  23  Borough                         object
#  24  X Coordinate (State Plane)      float64
#  25  Y Coordinate (State Plane)      float64
#  26  Park Facility Name              object
#  27  Park Borough                    object
#  28  School Name                     object
#  29  School Number                   object
#  30  School Region                   object
#  31  School Code                     object
#  32  School Phone Number             object
#  33  School Address                  object
#  34  School City                     object
#  35  School State                    object
#  36  School Zip                      object
#  37  School Not Found                object
#  38  School or Citywide Complaint    object
#  39  Vehicle Type                    object
#  40  Taxi Company Borough            object
#  41  Taxi Pick Up Location           object
#  42  Bridge Highway Name             object
#  43  Bridge Highway Direction        object
#  44  Road Ramp                       object
#  45  Bridge Highway Segment          object
#  46  Garage Lot Name                 object
#  47  Ferry Direction                 object
#  48  Ferry Terminal Name             object
#  49  Latitude                        float64
#  50  Longitude                       float64
#  51  Location                        object
# dtypes: float64(4), int64(1), object(47)
# memory usage: 707.4+ MB

# %%
df = df.sample(frac=1,random_state=42)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df = df[0:20000]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      20000 non-null  int64
#  1   Created Date                    20000 non-null  object
#  2   Closed Date                     19320 non-null  object
#  3   Agency                          20000 non-null  object
#  4   Agency Name                     20000 non-null  object
#  5   Complaint Type                  20000 non-null  object
#  6   Descriptor                      19943 non-null  object
#  7   Location Type                   13542 non-null  object
#  8   Incident Zip                    18593 non-null  object
#  9   Incident Address                15749 non-null  object
#  10  Street Name                     15745 non-null  object
#  11  Cross Street 1                  15691 non-null  object
#  12  Cross Street 2                  15584 non-null  object
#  13  Intersection Street 1           3924 non-null   object
#  14  Intersection Street 2           3924 non-null   object
#  15  Address Type                    19402 non-null  object
#  16  City                            18605 non-null  object
#  17  Landmark                        15 non-null     object
#  18  Facility Type                   2507 non-null   object
#  19  Status                          20000 non-null  object
#  20  Due Date                        5800 non-null   object
#  21  Resolution Action Updated Date  19839 non-null  object
#  22  Community Board                 20000 non-null  object
#  23  Borough                         20000 non-null  object
#  24  X Coordinate (State Plane)      18486 non-null  float64
#  25  Y Coordinate (State Plane)      18486 non-null  float64
#  26  Park Facility Name              20000 non-null  object
#  27  Park Borough                    20000 non-null  object
#  28  School Name                     20000 non-null  object
#  29  School Number                   19997 non-null  object
#  30  School Region                   19905 non-null  object
#  31  School Code                     19905 non-null  object
#  32  School Phone Number             20000 non-null  object
#  33  School Address                  20000 non-null  object
#  34  School City                     20000 non-null  object
#  35  School State                    20000 non-null  object
#  36  School Zip                      20000 non-null  object
#  37  School Not Found                52 non-null     object
#  38  School or Citywide Complaint    45 non-null     object
#  39  Vehicle Type                    18 non-null     object
#  40  Taxi Company Borough            15 non-null     object
#  41  Taxi Pick Up Location           202 non-null    object
#  42  Bridge Highway Name             44 non-null     object
#  43  Bridge Highway Direction        44 non-null     object
#  44  Road Ramp                       44 non-null     object
#  45  Bridge Highway Segment          44 non-null     object
#  46  Garage Lot Name                 9 non-null      object
#  47  Ferry Direction                 4 non-null      object
#  48  Ferry Terminal Name             12 non-null     object
#  49  Latitude                        18486 non-null  float64
#  50  Longitude                       18486 non-null  float64
#  51  Location                        18486 non-null  object
# dtypes: float64(4), int64(1), object(47)
# memory usage: 7.9+ MB

# %%
df = df[['Created Date','Complaint Type','Descriptor', 'Borough']]
df.head(10)
# Out:
#              Created Date          Complaint Type  \
# 0  05/19/2009 12:00:00 AM  Street Light Condition
# 1  01/20/2009 12:00:00 AM                    Snow
# 2  01/07/2009 12:00:00 AM  Street Light Condition
# 3  04/04/2009 12:00:00 AM            Water System
# 4  01/23/2009 12:00:00 AM              Electrical
# 5  04/24/2009 12:00:00 AM                NONCONST
# 6  08/13/2009 12:00:00 AM                NONCONST
# 7  10/22/2009 12:00:00 AM        Street Condition
# 8  03/30/2009 12:00:00 AM     Hazardous Materials
# 9  03/07/2009 12:00:00 AM    GENERAL CONSTRUCTION
#
#                                        Descriptor        Borough
# 0                                Street Light Out         QUEENS
# 1                       5 Un-Plowed/Spread Street       BROOKLYN
# 2                                Street Light Out  STATEN ISLAND
# 3  Possible Water Main Break (Use Comments) (WA1)          BRONX
# 4             Electrical Wiring Defective/Exposed       BROOKLYN
# 5                                  SMOKE-DETECTOR    Unspecified
# 6                                          VERMIN    Unspecified
# 7                            Failed Street Repair          BRONX
# 8                             Chemical Odor (HD1)         QUEENS
# 9                                         WINDOWS    Unspecified

# %%
#missing values
df.isna().sum()
# Out:
# Created Date       0
# Complaint Type     0
# Descriptor        57
# Borough            0
# dtype: int64

# %%
#filling missing values
df['Complaint Type'] = df['Complaint Type'].fillna('Unknown')
df['Descriptor'] = df['Descriptor'].fillna('Unknown')
df['Borough'] = df['Borough'].fillna('Unknown')

# %%
df.shape
# Out:
# (20000, 4)

# %%
df['text'] = df['Complaint Type'] + ' ' + df['Descriptor']

# %%
df['Complaint Type'].unique()
# Out:
# array(['Street Light Condition', 'Snow', 'Water System', 'Electrical',
#        'NONCONST', 'Street Condition', 'Hazardous Materials',
#        'GENERAL CONSTRUCTION', 'PLUMBING', 'Sewer', 'HEATING',
#        'Sanitation Condition', 'Noise', 'Elevator', 'Damaged Tree',
#        'PAINT - PLASTER', 'Noise - Commercial', 'Special Enforcement',
#        'Street Sign - Damaged', 'ELECTRIC', 'Noise - Street/Sidewalk',
#        'General Construction/Plumbing', 'Dirty Conditions',
#        'Indoor Air Quality', 'DOE Complaint or Compliment', 'APPLIANCE',
#        'Taxi Complaint', 'Missed Collection (All Materials)',
#        'Food Establishment', 'Overflowing Litter Baskets',
#        'Blocked Driveway', 'Building/Use', 'Consumer Complaint',
#        'Traffic Signal Condition',
#        'DCA / DOH New License Application Request', 'Broken Muni Meter',
#        'Rodent', 'Portable Toilet', 'Boilers', 'Broken Parking Meter',
#        'Lead', 'Drinking', 'Air Quality', 'Noise - Vehicle',
#        'Derelict Vehicle', 'Dead Tree', 'Other Enforcement',
#        'Overgrown Tree/Branches', 'Teaching/Learning/Instruction',
#        'Graffiti', 'Food Poisoning', 'Highway Condition', 'Water Quality',
#        'Noise - Park', 'Root/Sewer/Sidewalk Condition',
#        'School Maintenance', 'Vending', 'Water Conservation', 'Plumbing',
#        'Asbestos', 'Emergency Response Team (ERT)', 'BEST/Site Safety',
#        'Derelict Vehicles', 'For Hire Vehicle Complaint',
#        'Unsanitary Animal Pvt Property', 'Maintenance or Facility',
#        'Public Payphone Complaint', 'City Vehicle Placard Complaint',
#        'Litter Basket / Request', 'Recycling Enforcement',
#        'Street Sign - Missing', 'Posting Advertisement', 'Safety',
#        'Sidewalk Condition', 'Discipline and Suspension',
#        'Miscellaneous Categories', 'Homeless Encampment',
#        'Non-Residential Heat', 'Bike/Roller/Skate Chronic',
#        'Urinating in Public', 'Tree Work Permit Request',
#        'Violation of Park Rules', 'Illegal Animal Kept as Pet', 'Plant',
#        'Noise - House of Worship', 'Disorderly Youth',
#        'Special Projects Inspection Team (SPIT)',
#        'Beach/Pool/Sauna Complaint', 'Unsanitary Pigeon Condition',
#        'CONSTRUCTION', 'DOF Property - Owner Issue',
#        'Sweeping/Missed-Inadequate',
#        'Investigations and Discipline (IAD)', 'Vacant Lot',
#        'Parent Leadership', 'Bus Stop Shelter Placement', 'Ferry Inquiry',
#        'Street Sign - Dangling', 'Health', 'DOF Property - Payment Issue',
#        'Smoking', 'Taxi Compliment', 'Illegal Tree Damage',
#        'DOF Property - City Rebate', 'Calorie Labeling', 'Found Property',
#        'Industrial Waste', 'Cranes and Derricks', 'Animal in a Park',
#        'Stalled Sites', 'Window Guard', 'Registration and Transfers',
#        'Bridge Condition', 'Highway Sign - Damaged', 'Unleashed Dog',
#        'Parking Card', 'Mold', 'Illegal Animal Sold', 'Ferry Complaint',
#        'Scaffold Safety', 'Public Toilet', 'Unsanitary Animal Facility',
#        'Illegal Fireworks', 'Municipal Parking Facility',
#        'Animal Facility - No Permit', 'Senior Center Complaint'],
#       dtype=object)

# %%
df['Complaint Type'].value_counts()
# Out:
# Complaint Type
# HEATING                        2583
# Street Light Condition         1479
# GENERAL CONSTRUCTION           1362
# PLUMBING                       1234
# Street Condition               1154
#                                ...
# Public Toilet                     1
# Unsanitary Animal Facility        1
# Municipal Parking Facility        1
# Animal Facility - No Permit       1
# Illegal Animal Sold               1
# Name: count, Length: 126, dtype: int64

# %%
df.groupby('Complaint Type').size()
# Out:
# Complaint Type
# APPLIANCE                      173
# Air Quality                    107
# Animal Facility - No Permit      1
# Animal in a Park                13
# Asbestos                        15
#                               ...
# Violation of Park Rules         23
# Water Conservation              39
# Water Quality                   14
# Water System                   697
# Window Guard                    11
# Length: 126, dtype: int64

# %% [markdown]
# ### Text Preprocessing

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(sentence):
    text = str(sentence).lower()  # Convert to lowercase
    
    text = re.sub(r"http\S+|www\S+", " ", text) # Remove URLs
    
    text = re.sub(r"[^a-zA-Z0-9]", " ", text) # Remove special characters

    words = text.split() 
    
# Remove stopwords + apply lemmatization
    
    words = [x for x in words if x not in stop_words]
    words = [lemmatizer.lemmatize(word, 'v') for word in words]

    return " ".join(words)

# %%
df['clean_text'] = df['text'].apply(preprocess)
df[['text','clean_text']].head()
# Out:
#                                                 text  \
# 0            Street Light Condition Street Light Out
# 1                     Snow 5 Un-Plowed/Spread Street
# 2            Street Light Condition Street Light Out
# 3  Water System Possible Water Main Break (Use Co...
# 4     Electrical Electrical Wiring Defective/Exposed
#
#                                           clean_text
# 0                street light condition street light
# 1                       snow 5 un plow spread street
# 2                street light condition street light
# 3  water system possible water main break use com...
# 4        electrical electrical wire defective expose

# %%
for i in range(10):
    print(df['clean_text'][i], '- ', df['Complaint Type'][i])
    print()
# Out:
# street light condition street light -  Street Light Condition
#
# snow 5 un plow spread street -  Snow
#
# street light condition street light -  Street Light Condition
#
# water system possible water main break use comment wa1 -  Water System
#
# electrical electrical wire defective expose -  Electrical
#
# nonconst smoke detector -  NONCONST
#
# nonconst vermin -  NONCONST
#
# street condition fail street repair -  Street Condition
#
# hazardous materials chemical odor hd1 -  Hazardous Materials
#
# general construction windows -  GENERAL CONSTRUCTION

# %% [markdown]
# ### Exploratory Data Analysis

# %%
top_15 = df['Complaint Type'].value_counts().head(10)

plt.figure(figsize=(20,8))
sns.barplot(x = top_15.index, y = top_15.values, palette = 'husl', hue = top_15.index, legend = False)
plt.title('Top 10 Complaint Categories')
plt.tight_layout()
plt.show()

# %%
complaint_percentage = df['Complaint Type'].value_counts(normalize=True).head(10)*100

plt.figure(figsize=(20,8))
sns.barplot(x = complaint_percentage.index, y = complaint_percentage.values)
plt.ylabel('Percentage')
plt.title('Top 10 Complaint Percentage Distribution')
plt.tight_layout()
plt.show()

# %%
colors = sns.color_palette("husl", 10)

df['Borough'].value_counts().plot(kind='bar', color = colors)
plt.title("Complaints by Borough")
plt.xlabel("Borough")
plt.ylabel("Count")
plt.show()

# %%
#Time Series Complaint Trend Analysis
df['Created Date'] = pd.to_datetime(
    df['Created Date'],
    format='%m/%d/%Y %I:%M:%S %p',
    errors='coerce'
)

df['Created Date'].dt.month.value_counts().sort_index().plot()
plt.title("Complaints Over Months")
plt.xlabel("Month")
plt.ylabel("Number of Complaints")
plt.show()

# %% [markdown]
# ### Word Clouds

# %%
text_data = " ".join(df['clean_text'])

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.title("Word Cloud of Complaints")
plt.show()

# %% [markdown]
# ### N-grams Frequency Distribution

# %%
#Unigram

vectorizer = CountVectorizer(ngram_range=(1,1), max_features=10)
X = vectorizer.fit_transform(df['clean_text'])

words = vectorizer.get_feature_names_out()
counts = X.sum(axis=0).A1

unigram_df = pd.DataFrame({'word': words, 'count': counts})
unigram_df.sort_values(by='count', ascending=False)
# Out:
#            word  count
# 4          heat   5211
# 8        street   5015
# 1     condition   4573
# 5         light   2887
# 2  construction   2258
# 3       general   2098
# 7         plumb   1999
# 9         water   1620
# 6         noise   1588
# 0         build   1004

# %%
#bigram

vectorizer = CountVectorizer(ngram_range=(2,2), max_features=10)
X = vectorizer.fit_transform(df['clean_text'])

bigrams = vectorizer.get_feature_names_out()
counts = X.sum(axis=0).A1

bigram_df = pd.DataFrame({'bigram': bigrams, 'count': counts})
bigram_df.sort_values(by='count', ascending=False)
# Out:
#                  bigram  count
# 7          street light   2747
# 3             heat heat   2583
# 2  general construction   2062
# 4       light condition   1479
# 0      condition street   1187
# 6      street condition   1167
# 5         paint plaster    972
# 1    construction plumb    702
# 8        traffic signal    702
# 9          water system    697

# %%
unigram_df.plot(x='word', y='count', kind='bar', color=colors)
plt.title("Top Words in Complaints")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.show()
